# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris
# hi

# %%
iris = load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris_df['turlari'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
np.unique(iris_df['turlari'])
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
grouped = iris_df.groupby('turlari')
grouped.mean()
# Out:
# C:\Users\Shon Dev\AppData\Local\Temp\ipykernel_14528\3707175494.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = iris_df.groupby('turlari')
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# turlari
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# turlari
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %%
sns.pairplot(iris_df, hue='turlari')
plt.show()

# %%
sns.heatmap(iris_df[['sepal length(cm)','sepal width (cm)','petal length(cm)', 'petal width (cm)']].corr{}, annot=True)
plt.show()
# Out:
#   Cell In[10], line 1
#     sns.heatmap(iris_df[['sepal length(cm)','sepal width (cm)','petal length(cm)', 'petal width (cm)']].corr{}, annot=True)
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# prompt: correct:
# sns.heatmap(iris_df[['sepal length(cm)','sepal width (cm)','petal length(cm)', 'petal width (cm)']].corr{}, annot=True)
# plt.show()

sns.heatmap(iris_df[['sepal length (cm)','sepal width (cm)','petal length (cm)', 'petal width (cm)']].corr(), annot=True)
plt.show()

# %%
# prompt: create correclation heatmap use sns to create heatmap for iris data frame

correlation_matrix = iris_df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Heatmap of Iris Features')
plt.show()

# %%
# prompt: # standardization

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x = iris_df[['sepal length (cm)','sepal width (cm)','petal length (cm)', 'petal width (cm)']].values
y = iris_df['turlari']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Pre-processing uchun muhim # standardization (x- o'rta qiymat) / standart deviation

# %%
x_train
# Out:
# array([[ 0.54379452, -1.20516688,  0.66011716,  0.87694487],
#        [-1.16063607, -1.20516688,  0.3739392 ,  0.60927275],
#        [ 2.49171521,  1.73768248,  1.46141545,  1.01078094],
#        [-1.16063607,  0.15307129, -1.34312856, -1.3982682 ],
#        [-0.18667573, -0.5260478 ,  0.14499683,  0.07392849],
#        [ 1.88298999, -0.5260478 ,  1.28970867,  0.87694487],
#        [ 0.42204948,  0.83219037,  0.88905953,  1.41228913],
#        [-0.43016582,  2.64317459, -1.40036415, -1.3982682 ],
#        [ 0.30030444, -0.97879385,  1.00353071,  0.20776456],
#        [-0.55191086, -0.07330174,  0.3739392 ,  0.34160062],
#        [ 1.39600982,  0.37944431,  0.48841039,  0.20776456],
#        [ 2.24822512,  1.73768248,  1.63312223,  1.27845306],
#        [ 0.05681435, -0.07330174,  0.20223243,  0.34160062],
#        [-1.03889103,  1.28493642, -1.40036415, -1.3982682 ],
#        [ 0.78728461,  0.37944431,  0.71735275,  1.01078094],
# ...

# %%
### Tensors and deep learning

# %%
# reshape the torch
torch =
# Out:
#   Cell In[16], line 2
#     GeneratorExit create plotting Code
#                   ^
# SyntaxError: invalid syntax

# %%
tensor =
# Out:
# 25
